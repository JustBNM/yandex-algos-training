# %% [markdown]
# # [Контест](https://contest.yandex.ru/contest/28730/enter/)
# # Домашнее задание #1 "Сложность, тестирование, особые случаи"

# %% [markdown]
# # A. Interactor

# %% [markdown]
# Лена руководит разработкой тестирующей системы, в которой реализованы интерактивные задачи. До заверщения очередной стадии проекта осталось написать модуль, определяющий итоговый вердикт системы для интерактивной задачи. Итоговый вердикт определяется из кода завершения задачи, вердикта интерактора и вердикта чекера по следующим правилам:
#
# Вердикт чекера и вердикт интерактора — это целые числа от 0 до 7 включительно. Код завершения задачи — это целое число от -128 до 127 включительно. Если интерактор выдал вердикт 0, итоговый вердикт равен 3 в случае, если программа завершилась с ненулевым кодом, и вердикту чекера в противном случае. Если интерактор выдал вердикт 1, итоговый вердикт равен вердикту чекера. Если интерактор выдал вердикт 4, итоговый вердикт равен 3 в случае, если программа завершилась с ненулевым кодом, и 4 в противном случае. Если интерактор выдал вердикт 6, итоговый вердикт равен 0. Если интерактор выдал вердикт 7, итоговый вердикт равен 1. В остальных случаях итоговый вердикт равен вердикту интерактора. Ваша задача — реализовать этот модуль.

# %%
r = int(input()) # код завершения задачи
i = int(input()) # вердикт интерактора
c = int(input()) # вердикт чекера

result = i # итоговый вердикт

if i == 0:
    if r != 0:
        result = 3
    else:
        result = c
elif i == 1:
    result = c
elif i == 4:
    if r != 0:
        result = 3
    else:
        result = 4
elif i == 6:
    result = 0
elif i == 7:
    result = 1
print(result)
# Out:
# -3
# 2
# 4
# 2

# %% [markdown]
# # B. Кольцевая линия метро

# %% [markdown]
# Витя работает недалеко от одной из станций кольцевой линии Московского метро, а живет рядом с другой станцией той же линии. Требуется выяснить, мимо какого наименьшего количества промежуточных станций необходимо проехать Вите по кольцу, чтобы добраться с работы домой.

# %%
n, i, j = map(int, input().split())

number_of_stations `= min(abs(i-j), abs(min(i,j) + n - max(i,j))) - 1
print(number_of_stations)
# Out:
# 10 1 9
# 1

# %% [markdown]
# # C. Даты

# %% [markdown]
# Как известно, два наиболее распространённых формата записи даты — это европейский (сначала день, потом месяц, потом год) и американски (сначала месяц, потом день, потом год). Системный администратор поменял дату на одном из бэкапов и сейчас хочет вернуть дату обратно. Но он не проверил, в каком формате дата используется в системе. Может ли он обойтись без этой информации?
# Иначе говоря, вам даётся запись некоторой корректной даты. Требуется выяснить, однозначно ли по этой записи определяется дата даже без дополнительной информации о формате.

# %%
x, y, z = map(int, input().split())

result = 0
if x > 12 or y > 12 or x ==y:
    result = 1
print(result)
# Out:
# 3 3 2067
# 0

# %% [markdown]
# # D. Строительство школы

# %% [markdown]
# В деревне Интернетовка все дома расположены вдоль одной улицы по одну сторону от нее. По другую сторону от этой улицы пока ничего нет, но скоро все будет – школы, магазины, кинотеатры и т.д.
#
# Для начала в этой деревне решили построить школу. Место для строительства школы решили выбрать так, чтобы суммарное расстояние, которое проезжают ученики от своих домов до школы, было минимально.
#
# План деревни можно представить в виде прямой, в некоторых целочисленных точках которой находятся дома учеников. Школу также разрешается строить только в целочисленной точке этой прямой (в том числе разрешается строить школу в точке, где расположен один из домов – ведь школа будет расположена с другой стороны улицы).
#
# Напишите программу, которая по известным координатам домов учеников поможет определить координаты места строительства школы.

# %%
N = int(input())
coordinates = list(map(int, input().split()))

best_place = 0

if N>0:
    best_place = coordinates[N//2]

print(best_place)
# Out:
# 4
# 1 2 3 4
# 3

# %% [markdown]
# # E. Точка и треугольник

# %% [markdown]
# На координатной плоскости расположены равнобедренный прямоугольный треугольник ABC с длиной катета d и точка X. Катеты треугольника лежат на осях координат, а вершины расположены в точках: A (0,0), B (d,0), C (0,d).
#
# Напишите программу, которая определяет взаимное расположение точки X и треугольника. Если точка X расположена внутри или на сторонах треугольника, выведите 0. Если же точка находится вне треугольника, выведите номер ближайшей к ней вершины.

# %%
d = int(input())
x, y = map(int, input().split())
# Универсальное решение для любого положения треугольника

# Псевдоскалярное (косое) произведение: https://habr.com/ru/post/148325/
# Если a = (x1, y1); b = (x2, y2)
# [a, b] = x1y2 - x2y1
# [a, b] > 0: слева от вектора ; [a, b] < 0: справа от вектора
# a - вектора треугольника, b - вектор точки
# Треугольник (0,0), (d, 0), (0, d)
# Вектора: (d, 0) (0, d), (d, -d)
D_1 = d*(y-d) - x*(-d) # слева от биссектрисы
D_2 = d*y - x*0 # Внутри катетов
D_3 = 0*y - x*d # Внутри катетов

if D_1 <= 0 and D_2 >= 0 and D_3 <= 0: # Лежит внутри
    print(0)
else: # Лежит вне, считаем расстояние в квадрате до всех вершин, берем минимальную
    d_1 = (x-0)**2 + (y-0)**2
    d_2 = (x-d)**2 + (y-0)**2
    d_3 = (x-0)**2 + (y-d)**2
    distances = [d_1, d_2, d_3]
    print(distances.index(min(distances))+1)
    
# Другое решение: отсекаем все четверти кроме 1,
# а потом задаем уравнение прямой x+y = d
# Если x+y > d, то точка лежит вне треугольника,
# Если x+y < d, - то внутри
# Out:
# 4
# 2 2
# 0
